# %%
import requests
import json
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Define the function that makes call to the API
key = '2s2piMwI01ZboAS5H451mWKEK4E5i93kvrUGSlxp'



def make_call(chamber, congress_number):
    s = 'https://api.propublica.org/congress/v1/'+ str(congress_number) + '/'+ chamber + '/members.json'

    response = requests.get(s, headers = {'X-API-Key': key})

    r = json.loads(response.content.decode('utf-8'))

    return r

# %%
# Define df that we'll be putting the data in 
results = pd.DataFrame(columns=['first_name', 'last_name', 
                                'party', 'gender', 'chamber', 'congress_number', 'DOB'])


# Create a dictionary that will allow you to loop through house and senate or just senate, 
# depending on the congress number that you're looking at

bar = {}
for i in range(102, 117):
    bar[i] = ['house', 'senate']

for i in range(80, 102):
    bar[i] = ['senate']

# %%
# Make the call, looping through both house and senate for congresses 102 - 116 inclusive
# Looping through only senate for congresses 80-101 inclusive
for i in range(80, 117):
    for c in bar[i]:
        call = make_call(c, i)

        first_name = []
        last_name = []
        party = []
        gender = []
        chamber = []
        congress_number = []
        DOB = []

        temp = pd.DataFrame(columns=['first_name', 'last_name', 'party', 'gender', 'chamber', 'congress_number', 'DOB'])

        for element in call['results'][0]['members']:
            first_name.append(element['first_name'])
            last_name.append(element['last_name'])
            party.append(element['party'])
            gender.append(element['gender'])
            chamber.append(c)
            congress_number.append(i)
            DOB.append(element['date_of_birth'][0:4])

        temp.first_name, temp.last_name, temp.party, temp.gender, temp.chamber, temp.congress_number, temp.DOB = first_name, last_name, party, gender, chamber, congress_number, DOB


        results = results.append(temp, ignore_index = True)

    print(i)
# Out:
# 80
# 81
# 82
# 83
# 84
# 85
# 86
# 87
# 88
# 89
# 90
# 91
# 92
# 93
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 104
# 105
# 106
# 107
# 108
# 109
# 110
# 111
# 112
# 113
# 114
# 115
# 116

# %%
results.to_csv('raw_results_from_propublica.csv')

# %%
# Now make sure we don't have any duplicates:
# 'chamber' is there in case someone is both a senator and a member of the house (not technically possible)
# 'congress_number' is here to prevent deleting members that have been there for more than one congress
# Duplicates arise when people make it to congress and change party

results.drop_duplicates(['first_name', 'last_name', 'chamber', 'congress_number'], inplace=True)

# Currently there are ID and I are two different notations for independent
# Need to consolidate both labels to a single one

results.replace({'party': {'ID': 'I'}}, inplace = True)

# %%
# Approx 1e4 rows
results.shape
# Out:
# (10567, 7)

# %%
# Here we replace the empty cells with NaN as the empty cells are not detected by panda's isna() function
results.replace(r'^\s*$', np.nan, regex=True, inplace = True)
# We also replace python's None with NaN
results.fillna(value=pd.np.nan, inplace=True)

# %%
# Now we have the dataframe that we want
results.head(10)
# Out:
#   first_name  last_name party gender chamber  congress_number   DOB
# 0     George      Aiken     R      M  senate               80  1892
# 1    Raymond    Baldwin     R      M  senate               80  1893
# 2     Joseph       Ball     R      M  senate               80  1905
# 3      Alben    Barkley     D    NaN  senate               80  1877
# 4   Theodore      Bilbo     D      M  senate               80   NaN
# 5      Ralph   Brewster     R      M  senate               80  1888
# 6       John    Bricker     R      M  senate               80   NaN
# 7      Henry    Bridges     R      M  senate               80  1898
# 8    Charles     Brooks     R      M  senate               80  1897
# 9     Joseph  Broughton     D      M  senate               80  1888

# %%
# Annoyingly, there are a four people for whom we have neither the DOB nor the gender: 
# Scott Lucas, Elmer Thomas, Lyndon Johnson and Noris Cotton. 

results[(results.DOB.isna() == True) & (results.gender.isna() == True)]
# Out:
#      first_name last_name party gender chamber  congress_number  DOB
# 52        Scott     Lucas     D    NaN  senate               80  NaN
# 88        Elmer    Thomas     D    NaN  senate               80  NaN
# 150      Lyndon   Johnson     D    NaN  senate               81  NaN
# 162       Scott     Lucas     D    NaN  senate               81  NaN
# 198       Elmer    Thomas     D    NaN  senate               81  NaN
# 259      Lyndon   Johnson     D    NaN  senate               82  NaN
# 340      Norris    Cotton     R    NaN  senate               83  NaN
# 375      Lyndon   Johnson     D    NaN  senate               83  NaN
# 451      Norris    Cotton     R    NaN  senate               84  NaN
# 480      Lyndon   Johnson     D    NaN  senate               84  NaN
# 555      Norris    Cotton     R    NaN  senate               85  NaN
# 582      Lyndon   Johnson     D    NaN  senate               85  NaN
# 659      Norris    Cotton     R    NaN  senate               86  NaN
# 687      Lyndon   Johnson     D    NaN  senate               86  NaN
# 767      Norris    Cotton     R    NaN  senate               87  NaN
# 793      Lyndon   Johnson     D    NaN  senate               87  NaN
# 871      Norris    Cotton     R    NaN  senate               88  NaN
# 979      Norris    Cotton     R    NaN  senate               89  NaN
# 1085     Norris    Cotton     R    NaN  senate               90  NaN
# 1187     Norris    Cotton     R    NaN  senate               91  NaN
# 1296     Norris    Cotton     R    NaN  senate               92  NaN
# 1401     Norris    Cotton     R    NaN  senate               93  NaN
# 1507     Norris    Cotton     R    NaN  senate               94  NaN

# %%
# Manually checked that they were all men, 
# so we can just replace the gender field for these rows with 'M', as otherwise the gender_df function will 
# throw an error

results.loc[(results.DOB.isna() == True) & (results.gender.isna() == True), ['gender']] = 'M'

# %%
# Now we don't have that problem anymore: returns an empty dataframe
results[(results.DOB.isna() == True) & (results.gender.isna() == True)]
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, party, gender, chamber, congress_number, DOB]
# Index: []

# %%
# How many people are missing gender? 
len(results[results.gender.isna() == True])
# 500
# Out:
# 500

# %%
# Now we need to isolate the subset of members that has NA gender but has a DOB
# should be the same number as cell above
len(results[(results.gender.isna() == True) & (results.DOB.isna() == False)])

# But it looks like we have DOB info for all those whose gender is missing, which is good
# Out:
# 500

# %%
# We want to change the DOB of members to be at a minimum of 1880, because that's the lowest parameter for age
# accepted by the gender_df function
# Last thing we need to do before predicting gender is to create a series which has the method that the
# gender() function in R will use to predict gender.
# 'ssa' for DOBs that are 1930 and above, 'ipums' for everything else

# It looks like the data in our DOB series is of str type. First need to convert it to numeric

results.DOB = pd.to_numeric(results.DOB)

results['method'] = results.DOB.apply(lambda x: 'ssa' if x >= 1930 else 'ipums')

# %%
results
# Out:
#       first_name   last_name party gender chamber  congress_number     DOB  \
# 0         George       Aiken     R      M  senate               80  1892.0
# 1        Raymond     Baldwin     R      M  senate               80  1893.0
# 2         Joseph        Ball     R      M  senate               80  1905.0
# 3          Alben     Barkley     D    NaN  senate               80  1877.0
# 4       Theodore       Bilbo     D      M  senate               80     NaN
# 5          Ralph    Brewster     R      M  senate               80  1888.0
# 6           John     Bricker     R      M  senate               80     NaN
# 7          Henry     Bridges     R      M  senate               80  1898.0
# 8        Charles      Brooks     R      M  senate               80  1897.0
# 9         Joseph   Broughton     D      M  senate               80  1888.0
# 10       Clayton        Buck     R    NaN  senate               80  1890.0
# 11          Vera   Bushfield     R      F  senate               80  1889.0
# 12        Harlan   Bushfield     R      M  senate               80  1882.0
# 13          Hugh      Butler     R      M  senate               80     NaN
# 14         Harry        Byrd     D      M  senate               80  1887.0
# 15         Harry        Cain     R      M  senate               80  1906.0
# 16         Homer    Capehart     R      M  senate               80  1897.0
# 17        Arthur      Capper     R      M  senate               80  1865.0
# 18        Dennis      Chavez     D    NaN  senate               80  1888.0
# 19        Thomas    Connally     D      M  senate               80  1877.0
# 20          John      Cooper     R      M  senate               80  1901.0
# 21           Guy      Cordon     R      M  senate               80  1890.0
# 22       Forrest     Donnell     R    NaN  senate               80  1884.0
# 23      Sheridan      Downey     D    NaN  senate               80  1884.0
# 24         Henry    Dworshak     R      M  senate               80  1894.0
# 25         James    Eastland     D      M  senate               80  1904.0
# 26         Zales       Ecton     R    NaN  senate               80  1898.0
# 27         Allen    Ellender     D    NaN  senate               80  1890.0
# 28       William      Feazel     D      M  senate               80  1895.0
# 29         Homer    Ferguson     R      M  senate               80  1889.0
# ...          ...         ...   ...    ...     ...              ...     ...
# 10567        Jim       Risch     R      M  senate              116  1943.0
# 10568        Pat     Roberts     R      M  senate              116  1936.0
# 10569       Mitt      Romney     R      M  senate              116  1947.0
# 10570      Jacky       Rosen     D      F  senate              116  1957.0
# 10571       Mike      Rounds     R      M  senate              116  1954.0
# 10572      Marco       Rubio     R      M  senate              116  1971.0
# 10573    Bernard     Sanders     I      M  senate              116  1941.0
# 10574        Ben       Sasse     R      M  senate              116  1972.0
# 10575      Brian      Schatz     D      M  senate              116  1972.0
# 10576    Charles     Schumer     D      M  senate              116  1950.0
# 10577       Rick       Scott     R      M  senate              116  1952.0
# 10578        Tim       Scott     R      M  senate              116  1965.0
# 10579     Jeanne     Shaheen     D      F  senate              116  1947.0
# 10580    Richard      Shelby     R      M  senate              116  1934.0
# 10581    Kyrsten      Sinema     D      F  senate              116  1976.0
# 10582       Tina       Smith     D      F  senate              116  1958.0
# 10583     Debbie    Stabenow     D      F  senate              116  1950.0
# 10584        Dan    Sullivan     R      M  senate              116  1964.0
# 10585        Jon      Tester     D      M  senate              116  1956.0
# 10586       John       Thune     R      M  senate              116  1961.0
# 10587       Thom      Tillis     R      M  senate              116  1960.0
# 10588    Patrick      Toomey     R      M  senate              116  1961.0
# 10589        Tom       Udall     D      M  senate              116  1948.0
# 10590      Chris  Van Hollen     D      M  senate              116  1959.0
# 10591       Mark      Warner     D      M  senate              116  1954.0
# 10592  Elizabeth      Warren     D      F  senate              116  1949.0
# 10593    Sheldon  Whitehouse     D      M  senate              116  1955.0
# 10594      Roger      Wicker     R      M  senate              116  1951.0
# 10595        Ron       Wyden     D      M  senate              116  1949.0
# 10596       Todd       Young     R      M  senate              116  1972.0
#
#       method
# 0      ipums
# 1      ipums
# 2      ipums
# 3      ipums
# 4      ipums
# 5      ipums
# 6      ipums
# 7      ipums
# 8      ipums
# 9      ipums
# 10     ipums
# 11     ipums
# 12     ipums
# 13     ipums
# 14     ipums
# 15     ipums
# 16     ipums
# 17     ipums
# 18     ipums
# 19     ipums
# 20     ipums
# 21     ipums
# 22     ipums
# 23     ipums
# 24     ipums
# 25     ipums
# 26     ipums
# 27     ipums
# 28     ipums
# 29     ipums
# ...      ...
# 10567    ssa
# 10568    ssa
# 10569    ssa
# 10570    ssa
# 10571    ssa
# 10572    ssa
# 10573    ssa
# 10574    ssa
# 10575    ssa
# 10576    ssa
# 10577    ssa
# 10578    ssa
# 10579    ssa
# 10580    ssa
# 10581    ssa
# 10582    ssa
# 10583    ssa
# 10584    ssa
# 10585    ssa
# 10586    ssa
# 10587    ssa
# 10588    ssa
# 10589    ssa
# 10590    ssa
# 10591    ssa
# 10592    ssa
# 10593    ssa
# 10594    ssa
# 10595    ssa
# 10596    ssa
#
# [10567 rows x 8 columns]

# %%
# Now let's take a subset of this data that doesn't have a predicted gender, and put it into a csv file 
# for R to read
gender_to_be_determined = results[(results.gender.isna() == True) & (results.DOB.isna() == False)]

gender_to_be_determined.to_csv('gender_to_be_determined.csv')
gender_to_be_determined.shape[0]
# Out:
# 500

# %%
gender_to_be_determined[gender_to_be_determined.duplicated(subset=['first_name', 'last_name', 'DOB'], keep= False) == True].sort_values(by = 'first_name')
# Out:
#      first_name  last_name party gender chamber  congress_number     DOB  \
# 1580      Adlai  Stevenson     D    NaN  senate               94  1930.0
# 1367      Adlai  Stevenson     D    NaN  senate               92  1930.0
# 1692      Adlai  Stevenson     D    NaN  senate               95  1930.0
# 1794      Adlai  Stevenson     D    NaN  senate               96  1930.0
# 1472      Adlai  Stevenson     D    NaN  senate               93  1930.0
# 1260      Adlai  Stevenson     D    NaN  senate               91  1930.0
# 2785       Alan   Cranston     D    NaN  senate              102  1914.0
# 1176       Alan      Bible     D    NaN  senate               91  1909.0
# 2131       Alan   Cranston     D    NaN  senate              100  1914.0
# 1188       Alan   Cranston     D    NaN  senate               91  1914.0
# 438        Alan      Bible     D    NaN  senate               84  1909.0
# 539        Alan      Bible     D    NaN  senate               85  1909.0
# 2790       Alan      Dixon     D    NaN  senate              102  1927.0
# 2136       Alan      Dixon     D    NaN  senate              100  1927.0
# 1387       Alan      Bible     D    NaN  senate               93  1909.0
# 1724       Alan   Cranston     D    NaN  senate               96  1914.0
# 1282       Alan      Bible     D    NaN  senate               92  1909.0
# 323        Alan      Bible     D    NaN  senate               83  1909.0
# 1297       Alan   Cranston     D    NaN  senate               92  1914.0
# 2240       Alan      Dixon     D    NaN  senate              101  1927.0
# 1402       Alan   Cranston     D    NaN  senate               93  1914.0
# 1071       Alan      Bible     D    NaN  senate               90  1909.0
# 2235       Alan   Cranston     D    NaN  senate              101  1914.0
# 966        Alan      Bible     D    NaN  senate               89  1909.0
# 1508       Alan   Cranston     D    NaN  senate               94  1914.0
# 1927       Alan   Cranston     D    NaN  senate               98  1914.0
# 1932       Alan      Dixon     D    NaN  senate               98  1927.0
# 859        Alan      Bible     D    NaN  senate               88  1909.0
# 747        Alan      Bible     D    NaN  senate               87  1909.0
# 1827       Alan   Cranston     D    NaN  senate               97  1914.0
# ...         ...        ...   ...    ...     ...              ...     ...
# 965     Wallace    Bennett     R    NaN  senate               89  1898.0
# 640     Wallace    Bennett     R    NaN  senate               86  1898.0
# 1175    Wallace    Bennett     R    NaN  senate               91  1898.0
# 213     Wallace    Bennett     R    NaN  senate               82  1898.0
# 538     Wallace    Bennett     R    NaN  senate               85  1898.0
# 322     Wallace    Bennett     R    NaN  senate               83  1898.0
# 858     Wallace    Bennett     R    NaN  senate               88  1898.0
# 1070    Wallace    Bennett     R    NaN  senate               90  1898.0
# 1385    Wallace    Bennett     R    NaN  senate               93  1898.0
# 1280    Wallace    Bennett     R    NaN  senate               92  1898.0
# 437     Wallace    Bennett     R    NaN  senate               84  1898.0
# 66        Wayne      Morse     R    NaN  senate               80  1900.0
# 709       Wayne      Morse     D    NaN  senate               86  1900.0
# 602       Wayne      Morse     D    NaN  senate               85  1900.0
# 1135      Wayne      Morse     D    NaN  senate               90  1900.0
# 1028      Wayne      Morse     D    NaN  senate               89  1900.0
# 284       Wayne      Morse     R    NaN  senate               82  1900.0
# 398       Wayne      Morse     I    NaN  senate               83  1900.0
# 923       Wayne      Morse     D    NaN  senate               88  1900.0
# 502       Wayne      Morse     I    NaN  senate               84  1900.0
# 176       Wayne      Morse     R    NaN  senate               81  1900.0
# 817       Wayne      Morse     D    NaN  senate               87  1900.0
# 1486    Wendell   Anderson     I    NaN  senate               94  1933.0
# 1595    Wendell   Anderson     I    NaN  senate               95  1933.0
# 2247      Wyche     Fowler     D    NaN  senate              101  1940.0
# 2798      Wyche     Fowler     D    NaN  senate              102  1940.0
# 2144      Wyche     Fowler     D    NaN  senate              100  1940.0
# 26        Zales      Ecton     R    NaN  senate               80  1898.0
# 128       Zales      Ecton     R    NaN  senate               81  1898.0
# 237       Zales      Ecton     R    NaN  senate               82  1898.0
#
#      method
# 1580    ssa
# 1367    ssa
# 1692    ssa
# 1794    ssa
# 1472    ssa
# 1260    ssa
# 2785  ipums
# 1176  ipums
# 2131  ipums
# 1188  ipums
# 438   ipums
# 539   ipums
# 2790  ipums
# 2136  ipums
# 1387  ipums
# 1724  ipums
# 1282  ipums
# 323   ipums
# 1297  ipums
# 2240  ipums
# 1402  ipums
# 1071  ipums
# 2235  ipums
# 966   ipums
# 1508  ipums
# 1927  ipums
# 1932  ipums
# 859   ipums
# 747   ipums
# 1827  ipums
# ...     ...
# 965   ipums
# 640   ipums
# 1175  ipums
# 213   ipums
# 538   ipums
# 322   ipums
# 858   ipums
# 1070  ipums
# 1385  ipums
# 1280  ipums
# 437   ipums
# 66    ipums
# 709   ipums
# 602   ipums
# 1135  ipums
# 1028  ipums
# 284   ipums
# 398   ipums
# 923   ipums
# 502   ipums
# 176   ipums
# 817   ipums
# 1486    ssa
# 1595    ssa
# 2247    ssa
# 2798    ssa
# 2144    ssa
# 26    ipums
# 128   ipums
# 237   ipums
#
# [452 rows x 8 columns]

# %%
# R commands
# new <- read.csv('gender_to_be_determined.csv', stringsAsFactors = FALSE)

# The snippet below leads to a lot of duplicates generated, which means you get way more rows than you should
# when you merge back with the original df
# > test <- new %>% rowwise() %>% do(results = gender(.$first_name, years = .$DOB, method = .$method)) 
# %>% do(bind_rows(.$results))

# > write.csv(test, 'propublica_gender_determined.csv')


# Don't use the code below
### > gender_to_be_determined <- read.csv('gender_to_be_determined.csv', stringsAsFactors = FALSE)
### > test <- gender_df(gender_to_be_determined, name_col = 'first_name', year_col = c('DOB', 'DOB'), method = 'ssa')
### > write.csv(test, 'gender_determined.csv')

# %%
# Now let's open gender_determined.csv and modify it to make the merging with the original dataset somewhat easier

gender_determined = pd.read_csv('propublica_gender_determined.csv', index_col = 0)
gender_determined.shape
# Out:
# (440, 6)

# %%
gender_determined.head()
# Out:
#        name  proportion_male  proportion_female gender  year_min  year_max
# 1     Alben           1.0000             0.0000   male      1877      1877
# 2   Clayton           0.9743             0.0257   male      1890      1890
# 3    Dennis           1.0000             0.0000   male      1888      1888
# 4   Forrest           1.0000             0.0000   male      1884      1884
# 5  Sheridan           1.0000             0.0000   male      1884      1884

# %%
# We can drop the year_min column (same as year_max), and rename the year_max to DOB and use that to merge
gender_determined.drop('year_min', axis = 1, inplace= True)
gender_determined.rename(columns = {'year_max': 'DOB', 'name' : 'first_name', 'gender' : 'predicted_gender'}
                         , inplace = True)
# Also want to change 'male' to 'M' and 'female' to 'F'
gender_determined.replace({'predicted_gender' : {'male': 'M', 'female' : 'F'}}, inplace = True)

# %%
# At this point, probably a good idea to inspect whether there are any false positives, false negatives

#gender_determined[gender_determined.predicted_gender == 'F']
gender_determined[(gender_determined.predicted_gender == 'F') & (gender_determined.proportion_female < 0.90)]

# Beryl is actually a false positive! Need to change that in the merged datframe
# Out:
#     first_name  proportion_male  proportion_female predicted_gender   DOB
# 38     Francis           0.4519             0.5481                F  1896
# 57     Francis           0.4519             0.5481                F  1896
# 79     Francis           0.4519             0.5481                F  1896
# 98     Francis           0.4519             0.5481                F  1896
# 116    Francis           0.4519             0.5481                F  1896
# 137    Francis           0.4519             0.5481                F  1896
# 384      Beryl           0.2107             0.7893                F  1938

# %%
# need to remove rows from gender_determined, currently has ~ 17000 rows! 
# Drops down to 2720

gender_determined.drop_duplicates(subset = ['first_name', 'DOB', 'proportion_male'], inplace= True)
#gender_determined.shape

# %%
gender_determined[gender_determined.first_name == 'Ed']
# Out:
#     first_name  proportion_male  proportion_female predicted_gender   DOB
# 428         Ed              1.0                0.0                M  1948

# %%
gender_to_be_determined[gender_to_be_determined.first_name == 'Ed']
# Out:
#      first_name last_name party gender chamber  congress_number     DOB method
# 3464         Ed    Bryant     R    NaN   house              104  1948.0    ssa
# 4022         Ed    Bryant     R    NaN   house              105  1948.0    ssa
# 4575         Ed    Bryant     R    NaN   house              106  1948.0    ssa
# 5120         Ed    Bryant     R    NaN   house              107  1948.0    ssa

# %%
# I think we need to take the df returned from R, remove the duplicates, then merge it back with the dataframe
# that was given to R.
# Keep only the rows from the dataframe that was given to R, adding to it the relevant rows from 
# the gender_determined dataframe. Should have a resulting df whose length is equal that of the original dataframe
# Out:
# 10567

# %%
# Need to do a left join to make sure we don't get any duplicates. 
# The R function is throwing a bunch of duplicates (probably why it's slow), but can't quite figure out why.
# It gives the data we want though, and fixed easily enough with a left join once you've removed duplicates

# %%
# This is the right length (i.e. the same length as gender_to_be_determined, 500 rows)
len(gender_to_be_determined.merge(gender_determined, on = ['first_name', 'DOB'], how = 'left'))
# Out:
# 500

# %%
# This dataset will have to be re-merged with the original one it came from, 'results'
# Let's call this to_merge, and look at Nas, false positives
to_merge = gender_to_be_determined.merge(gender_determined, on = ['first_name', 'DOB'], how = 'left')
to_merge.head()
# Out:
#   first_name last_name party gender chamber  congress_number     DOB method  \
# 0      Alben   Barkley     D    NaN  senate               80  1877.0  ipums
# 1    Clayton      Buck     R    NaN  senate               80  1890.0  ipums
# 2     Dennis    Chavez     D    NaN  senate               80  1888.0  ipums
# 3    Forrest   Donnell     R    NaN  senate               80  1884.0  ipums
# 4   Sheridan    Downey     D    NaN  senate               80  1884.0  ipums
#
#    proportion_male  proportion_female predicted_gender
# 0           1.0000             0.0000                M
# 1           0.9743             0.0257                M
# 2           1.0000             0.0000                M
# 3           1.0000             0.0000                M
# 4           1.0000             0.0000                M

# %%
# Of the 500 rows we set up for analyis, how many don't have a predicted gender?

to_merge.predicted_gender.isna().value_counts()

# 60, which isn't too bad
# Out:
# False    440
# True      60
# Name: predicted_gender, dtype: int64

# %%
# Let's take a look at the rows for which we're missing names, to see if there's anything odd there
to_merge[to_merge.predicted_gender.isna() == True]
# Out:
#     first_name     last_name party gender chamber  congress_number     DOB  \
# 5        Zales         Ecton     R    NaN  senate               80  1898.0
# 7       Bourke  Hickenlooper     R    NaN  senate               80  1896.0
# 9     Spessard       Holland     D    NaN  senate               80  1892.0
# 14      Burnet       Maybank     D    NaN  senate               80  1899.0
# 27       Zales         Ecton     R    NaN  senate               81  1898.0
# 29      Bourke  Hickenlooper     R    NaN  senate               81  1896.0
# 31    Spessard       Holland     D    NaN  senate               81  1892.0
# 36      Burnet       Maybank     D    NaN  senate               81  1899.0
# 50       Zales         Ecton     R    NaN  senate               82  1898.0
# 53      Bourke  Hickenlooper     R    NaN  senate               82  1896.0
# 55    Spessard       Holland     D    NaN  senate               82  1892.0
# 60      Burnet       Maybank     D    NaN  senate               82  1899.0
# 74      Bourke  Hickenlooper     R    NaN  senate               83  1896.0
# 76    Spessard       Holland     D    NaN  senate               83  1892.0
# 83      Burnet       Maybank     D    NaN  senate               83  1899.0
# 99      Bourke  Hickenlooper     R    NaN  senate               84  1896.0
# 100   Spessard       Holland     D    NaN  senate               84  1892.0
# 119     Bourke  Hickenlooper     R    NaN  senate               85  1896.0
# 120   Spessard       Holland     D    NaN  senate               85  1892.0
# 127   Thruston        Morton     R    NaN  senate               85  1907.0
# 142     Bourke  Hickenlooper     R    NaN  senate               86  1896.0
# 143   Spessard       Holland     D    NaN  senate               86  1892.0
# 150   Thruston        Morton     R    NaN  senate               86  1907.0
# 166     Bourke  Hickenlooper     R    NaN  senate               87  1896.0
# 167   Spessard       Holland     D    NaN  senate               87  1892.0
# 175   Thruston        Morton     R    NaN  senate               87  1907.0
# 189     Bourke  Hickenlooper     R    NaN  senate               88  1896.0
# 190   Spessard       Holland     D    NaN  senate               88  1892.0
# 198   Thruston        Morton     R    NaN  senate               88  1907.0
# 212     Bourke  Hickenlooper     R    NaN  senate               89  1896.0
# 213   Spessard       Holland     D    NaN  senate               89  1892.0
# 221   Thruston        Morton     R    NaN  senate               89  1907.0
# 236     Bourke  Hickenlooper     R    NaN  senate               90  1896.0
# 237   Spessard       Holland     D    NaN  senate               90  1892.0
# 244   Thruston        Morton     R    NaN  senate               90  1907.0
# 261   Spessard       Holland     D    NaN  senate               91  1892.0
# 268      Adlai     Stevenson     D    NaN  senate               91  1930.0
# 290      Adlai     Stevenson     D    NaN  senate               92  1930.0
# 310      Adlai     Stevenson     D    NaN  senate               93  1930.0
# 329      Adlai     Stevenson     D    NaN  senate               94  1930.0
# 343  Kaneaster        Hodges     D    NaN  senate               95  1938.0
# 345      Spark     Matsunaga     D    NaN  senate               95  1916.0
# 349      Adlai     Stevenson     D    NaN  senate               95  1930.0
# 361      Spark     Matsunaga     D    NaN  senate               96  1916.0
# 365      Adlai     Stevenson     D    NaN  senate               96  1930.0
# 377      Spark     Matsunaga     D    NaN  senate               97  1916.0
# 393      Spark     Matsunaga     D    NaN  senate               98  1916.0
# 407      Spark     Matsunaga     D    NaN  senate               99  1916.0
# 412   Brockman         Adams     D    NaN  senate              100  1927.0
# 419      Wyche        Fowler     D    NaN  senate              100  1940.0
# 421      Spark     Matsunaga     D    NaN  senate              100  1916.0
# 425   Brockman         Adams     D    NaN  senate              101  1927.0
# 431      Wyche        Fowler     D    NaN  senate              101  1940.0
# 433      Spark     Matsunaga     D    NaN  senate              101  1916.0
# 439      Druie       Barnard     D    NaN   house              102  1922.0
# 448     Mervyn       Dymally     D    NaN   house              102  1926.0
# 453   Sedgwick         Green     R    NaN   house              102  1929.0
# 475   Brockman         Adams     D    NaN  senate              102  1927.0
# 480      Wyche        Fowler     D    NaN  senate              102  1940.0
# 490        Wes        Cooley     R    NaN   house              104  1932.0
#
#     method  proportion_male  proportion_female predicted_gender
# 5    ipums              NaN                NaN              NaN
# 7    ipums              NaN                NaN              NaN
# 9    ipums              NaN                NaN              NaN
# 14   ipums              NaN                NaN              NaN
# 27   ipums              NaN                NaN              NaN
# 29   ipums              NaN                NaN              NaN
# 31   ipums              NaN                NaN              NaN
# 36   ipums              NaN                NaN              NaN
# 50   ipums              NaN                NaN              NaN
# 53   ipums              NaN                NaN              NaN
# 55   ipums              NaN                NaN              NaN
# 60   ipums              NaN                NaN              NaN
# 74   ipums              NaN                NaN              NaN
# 76   ipums              NaN                NaN              NaN
# 83   ipums              NaN                NaN              NaN
# 99   ipums              NaN                NaN              NaN
# 100  ipums              NaN                NaN              NaN
# 119  ipums              NaN                NaN              NaN
# 120  ipums              NaN                NaN              NaN
# 127  ipums              NaN                NaN              NaN
# 142  ipums              NaN                NaN              NaN
# 143  ipums              NaN                NaN              NaN
# 150  ipums              NaN                NaN              NaN
# 166  ipums              NaN                NaN              NaN
# 167  ipums              NaN                NaN              NaN
# 175  ipums              NaN                NaN              NaN
# 189  ipums              NaN                NaN              NaN
# 190  ipums              NaN                NaN              NaN
# 198  ipums              NaN                NaN              NaN
# 212  ipums              NaN                NaN              NaN
# 213  ipums              NaN                NaN              NaN
# 221  ipums              NaN                NaN              NaN
# 236  ipums              NaN                NaN              NaN
# 237  ipums              NaN                NaN              NaN
# 244  ipums              NaN                NaN              NaN
# 261  ipums              NaN                NaN              NaN
# 268    ssa              NaN                NaN              NaN
# 290    ssa              NaN                NaN              NaN
# 310    ssa              NaN                NaN              NaN
# 329    ssa              NaN                NaN              NaN
# 343    ssa              NaN                NaN              NaN
# 345  ipums              NaN                NaN              NaN
# 349    ssa              NaN                NaN              NaN
# 361  ipums              NaN                NaN              NaN
# 365    ssa              NaN                NaN              NaN
# 377  ipums              NaN                NaN              NaN
# 393  ipums              NaN                NaN              NaN
# 407  ipums              NaN                NaN              NaN
# 412  ipums              NaN                NaN              NaN
# 419    ssa              NaN                NaN              NaN
# 421  ipums              NaN                NaN              NaN
# 425  ipums              NaN                NaN              NaN
# 431    ssa              NaN                NaN              NaN
# 433  ipums              NaN                NaN              NaN
# 439  ipums              NaN                NaN              NaN
# 448  ipums              NaN                NaN              NaN
# 453  ipums              NaN                NaN              NaN
# 475  ipums              NaN                NaN              NaN
# 480    ssa              NaN                NaN              NaN
# 490    ssa              NaN                NaN              NaN

# %%
# It looks like just a few members, let's see how many
set(to_merge[to_merge.predicted_gender.isna() == True].first_name)
# Turns out they're all male, let's put that information in
# Out:
# {'Adlai',
#  'Bourke',
#  'Brockman',
#  'Burnet',
#  'Druie',
#  'Kaneaster',
#  'Mervyn',
#  'Sedgwick',
#  'Spark',
#  'Spessard',
#  'Thruston',
#  'Wes',
#  'Wyche',
#  'Zales'}

# %%
# Counting them all as male, as they're all male, just with unusual names
to_merge.loc[to_merge.predicted_gender.isna() == True, 'predicted_gender'] = 'M'

# %%
# No more missing values
to_merge.predicted_gender.isna().value_counts()
# Out:
# False    500
# Name: predicted_gender, dtype: int64

# %%
# Let's take a look at who's predicted to be female:
to_merge[to_merge.predicted_gender == 'F']
# Francis Case, Almer Monroney, Beryl Anthony and Joan Horn
# Low confidence in Francis and Beryl , with a proportion female of 0.55 and 0.79,
# i.e. lower than the cutoff of 0.9 that we used in the previous dataset.
# Out:
#     first_name last_name party gender chamber  congress_number     DOB method  \
# 45     Francis      Case     R    NaN  senate               82  1896.0  ipums
# 61       Almer  Monroney     D    NaN  senate               82  1902.0  ipums
# 68     Francis      Case     R    NaN  senate               83  1896.0  ipums
# 84       Almer  Monroney     D    NaN  senate               83  1902.0  ipums
# 93     Francis      Case     R    NaN  senate               84  1896.0  ipums
# 106      Almer  Monroney     D    NaN  senate               84  1902.0  ipums
# 114    Francis      Case     R    NaN  senate               85  1896.0  ipums
# 125      Almer  Monroney     D    NaN  senate               85  1902.0  ipums
# 135    Francis      Case     R    NaN  senate               86  1896.0  ipums
# 148      Almer  Monroney     D    NaN  senate               86  1902.0  ipums
# 159    Francis      Case     R    NaN  senate               87  1896.0  ipums
# 173      Almer  Monroney     D    NaN  senate               87  1902.0  ipums
# 196      Almer  Monroney     D    NaN  senate               88  1902.0  ipums
# 219      Almer  Monroney     D    NaN  senate               89  1902.0  ipums
# 242      Almer  Monroney     D    NaN  senate               90  1902.0  ipums
# 437      Beryl   Anthony     D    NaN   house              102  1938.0    ssa
# 458       Joan      Horn     D    NaN   house              102  1936.0    ssa
#
#      proportion_male  proportion_female predicted_gender
# 45            0.4519             0.5481                F
# 61            0.0000             1.0000                F
# 68            0.4519             0.5481                F
# 84            0.0000             1.0000                F
# 93            0.4519             0.5481                F
# 106           0.0000             1.0000                F
# 114           0.4519             0.5481                F
# 125           0.0000             1.0000                F
# 135           0.4519             0.5481                F
# 148           0.0000             1.0000                F
# 159           0.4519             0.5481                F
# 173           0.0000             1.0000                F
# 196           0.0000             1.0000                F
# 219           0.0000             1.0000                F
# 242           0.0000             1.0000                F
# 437           0.2107             0.7893                F
# 458           0.0047             0.9953                F

# %%
to_merge[to_merge.first_name == 'Joan']
# Out:
#     first_name last_name party gender chamber  congress_number     DOB method  \
# 458       Joan      Horn     D    NaN   house              102  1936.0    ssa
#
#      proportion_male  proportion_female predicted_gender
# 458           0.0047             0.9953                F

# %%
# Francis case was male, Beryl anthony too
# Almer is a male, even though we have a 100% female proportion! For that name, the ssa and ipums have completely
# opposite predictions, 100% female in one case, 100% male in the other. 
# Only Joan is female, so let's change all the predicted genders back to male, save for joan horn

to_merge.loc[to_merge.first_name != 'Joan', 'predicted_gender'] = 'M'

# %%
# Only one predicted female. No false positives, there could be some false negatives
to_merge.predicted_gender.value_counts()
# Out:
# M    499
# F      1
# Name: predicted_gender, dtype: int64

# %%
# Check for false negatives, but all those are male
to_merge[(to_merge.predicted_gender == 'M') & (to_merge.proportion_male < 0.6)]
# Out:
#     first_name last_name party gender chamber  congress_number     DOB method  \
# 17     Francis     Myers     D    NaN  senate               80  1901.0  ipums
# 39     Francis     Myers     D    NaN  senate               81  1901.0  ipums
# 45     Francis      Case     R    NaN  senate               82  1896.0  ipums
# 61       Almer  Monroney     D    NaN  senate               82  1902.0  ipums
# 68     Francis      Case     R    NaN  senate               83  1896.0  ipums
# 84       Almer  Monroney     D    NaN  senate               83  1902.0  ipums
# 93     Francis      Case     R    NaN  senate               84  1896.0  ipums
# 106      Almer  Monroney     D    NaN  senate               84  1902.0  ipums
# 114    Francis      Case     R    NaN  senate               85  1896.0  ipums
# 125      Almer  Monroney     D    NaN  senate               85  1902.0  ipums
# 135    Francis      Case     R    NaN  senate               86  1896.0  ipums
# 148      Almer  Monroney     D    NaN  senate               86  1902.0  ipums
# 159    Francis      Case     R    NaN  senate               87  1896.0  ipums
# 173      Almer  Monroney     D    NaN  senate               87  1902.0  ipums
# 196      Almer  Monroney     D    NaN  senate               88  1902.0  ipums
# 219      Almer  Monroney     D    NaN  senate               89  1902.0  ipums
# 242      Almer  Monroney     D    NaN  senate               90  1902.0  ipums
# 437      Beryl   Anthony     D    NaN   house              102  1938.0    ssa
#
#      proportion_male  proportion_female predicted_gender
# 17            0.5379             0.4621                M
# 39            0.5379             0.4621                M
# 45            0.4519             0.5481                M
# 61            0.0000             1.0000                M
# 68            0.4519             0.5481                M
# 84            0.0000             1.0000                M
# 93            0.4519             0.5481                M
# 106           0.0000             1.0000                M
# 114           0.4519             0.5481                M
# 125           0.0000             1.0000                M
# 135           0.4519             0.5481                M
# 148           0.0000             1.0000                M
# 159           0.4519             0.5481                M
# 173           0.0000             1.0000                M
# 196           0.0000             1.0000                M
# 219           0.0000             1.0000                M
# 242           0.0000             1.0000                M
# 437           0.2107             0.7893                M

# %%
# We now have a dataset that we're happy to merge back with the original one that it was extracted from
# Easiest thing is probably to append this dataset to the previous one, and then remove duplicates 
# based on first name, last name, chamber, party, and DOB

results.head()
# Let's put the
# Out:
#   first_name last_name party gender chamber  congress_number     DOB method
# 0     George     Aiken     R      M  senate               80  1892.0  ipums
# 1    Raymond   Baldwin     R      M  senate               80  1893.0  ipums
# 2     Joseph      Ball     R      M  senate               80  1905.0  ipums
# 3      Alben   Barkley     D    NaN  senate               80  1877.0  ipums
# 4   Theodore     Bilbo     D      M  senate               80     NaN  ipums

# %%
results['proportion_male'] = np.nan
results['proportion_female'] = np.nan 
results['predicted_gender'] = np.nan

# %%
results.head()
# Out:
#   first_name last_name party gender chamber  congress_number     DOB method  \
# 0     George     Aiken     R      M  senate               80  1892.0  ipums
# 1    Raymond   Baldwin     R      M  senate               80  1893.0  ipums
# 2     Joseph      Ball     R      M  senate               80  1905.0  ipums
# 3      Alben   Barkley     D    NaN  senate               80  1877.0  ipums
# 4   Theodore     Bilbo     D      M  senate               80     NaN  ipums
#
#    proportion_male  proportion_female  predicted_gender
# 0              NaN                NaN               NaN
# 1              NaN                NaN               NaN
# 2              NaN                NaN               NaN
# 3              NaN                NaN               NaN
# 4              NaN                NaN               NaN

# %%
to_merge.head()
# Out:
#   first_name last_name party gender chamber  congress_number     DOB method  \
# 0      Alben   Barkley     D    NaN  senate               80  1877.0  ipums
# 1    Clayton      Buck     R    NaN  senate               80  1890.0  ipums
# 2     Dennis    Chavez     D    NaN  senate               80  1888.0  ipums
# 3    Forrest   Donnell     R    NaN  senate               80  1884.0  ipums
# 4   Sheridan    Downey     D    NaN  senate               80  1884.0  ipums
#
#    proportion_male  proportion_female predicted_gender
# 0           1.0000             0.0000                M
# 1           0.9743             0.0257                M
# 2           1.0000             0.0000                M
# 3           1.0000             0.0000                M
# 4           1.0000             0.0000                M

# %%
results = results.append(to_merge)

# %%
# Now, results will have duplicates, Alben for instance
results[results.first_name == 'Alben']
# Out:
#     first_name last_name party gender chamber  congress_number     DOB method  \
# 3        Alben   Barkley     D    NaN  senate               80  1877.0  ipums
# 105      Alben   Barkley     D    NaN  senate               81  1877.0  ipums
# 433      Alben   Barkley     D    NaN  senate               84  1877.0  ipums
# 0        Alben   Barkley     D    NaN  senate               80  1877.0  ipums
# 21       Alben   Barkley     D    NaN  senate               81  1877.0  ipums
# 89       Alben   Barkley     D    NaN  senate               84  1877.0  ipums
#
#      proportion_male  proportion_female predicted_gender
# 3                NaN                NaN              NaN
# 105              NaN                NaN              NaN
# 433              NaN                NaN              NaN
# 0                1.0                0.0                M
# 21               1.0                0.0                M
# 89               1.0                0.0                M

# %%
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, party, gender, chamber, congress_number, DOB, method, proportion_male, proportion_female, predicted_gender]
# Index: []

# %%
# Since we annotated all the names from to_merge, the only duplicates are going to have NaN in the predicted gender
# and in the gender columns. Let's drop those
# We started off with 10567 rows, should end up with that again

results.dropna(subset= ['gender', 'predicted_gender'], how = 'all', inplace= True)

# %%
results
# Out:
#     first_name  last_name party gender chamber  congress_number     DOB  \
# 0       George      Aiken     R      M  senate               80  1892.0
# 1      Raymond    Baldwin     R      M  senate               80  1893.0
# 2       Joseph       Ball     R      M  senate               80  1905.0
# 4     Theodore      Bilbo     D      M  senate               80     NaN
# 5        Ralph   Brewster     R      M  senate               80  1888.0
# 6         John    Bricker     R      M  senate               80     NaN
# 7        Henry    Bridges     R      M  senate               80  1898.0
# 8      Charles     Brooks     R      M  senate               80  1897.0
# 9       Joseph  Broughton     D      M  senate               80  1888.0
# 11        Vera  Bushfield     R      F  senate               80  1889.0
# 12      Harlan  Bushfield     R      M  senate               80  1882.0
# 13        Hugh     Butler     R      M  senate               80     NaN
# 14       Harry       Byrd     D      M  senate               80  1887.0
# 15       Harry       Cain     R      M  senate               80  1906.0
# 16       Homer   Capehart     R      M  senate               80  1897.0
# 17      Arthur     Capper     R      M  senate               80  1865.0
# 19      Thomas   Connally     D      M  senate               80  1877.0
# 20        John     Cooper     R      M  senate               80  1901.0
# 21         Guy     Cordon     R      M  senate               80  1890.0
# 24       Henry   Dworshak     R      M  senate               80  1894.0
# 25       James   Eastland     D      M  senate               80  1904.0
# 28     William     Feazel     D      M  senate               80  1895.0
# 29       Homer   Ferguson     R      M  senate               80  1889.0
# 30       Ralph   Flanders     R      M  senate               80  1880.0
# 31       James  Fulbright     D      M  senate               80  1905.0
# 32      Walter     George     D      M  senate               80  1878.0
# 33    Theodore      Green     D      M  senate               80  1867.0
# 34        John     Gurney     R      M  senate               80  1896.0
# 35        Carl      Hatch     D      M  senate               80  1889.0
# 36      Albert     Hawkes     R      M  senate               80  1878.0
# ..         ...        ...   ...    ...     ...              ...     ...
# 470     Harley   Staggers     D    NaN   house              102  1951.0
# 471     Jerome    Traxler     D    NaN   house              102  1931.0
# 472     Morris      Udall     D    NaN   house              102  1922.0
# 473   Chalmers      Wylie     R    NaN   house              102  1920.0
# 474        Gus     Yatron     D    NaN   house              102  1927.0
# 475   Brockman      Adams     D    NaN  senate              102  1927.0
# 476      Lloyd    Bentsen     D    NaN  senate              102  1921.0
# 477    Quentin    Burdick     D    NaN  senate              102  1908.0
# 478       Alan   Cranston     D    NaN  senate              102  1914.0
# 479       Alan      Dixon     D    NaN  senate              102  1927.0
# 480      Wyche     Fowler     D    NaN  senate              102  1940.0
# 481      Larry   Pressler     R    NaN  senate              102  1942.0
# 482     Steven      Symms     R    NaN  senate              102  1938.0
# 483      Sonny   Callahan     R    NaN   house              103  1932.0
# 484      Lloyd    Bentsen     D    NaN  senate              103  1921.0
# 485      Larry   Pressler     R    NaN  senate              103  1942.0
# 486         Ed     Bryant     R    NaN   house              104  1948.0
# 487        Jim       Bunn     R    NaN   house              104  1956.0
# 488      Sonny   Callahan     R    NaN   house              104  1932.0
# 489       Dick   Chrysler     R    NaN   house              104  1942.0
# 490        Wes     Cooley     R    NaN   house              104  1932.0
# 491        Dan      Frisa     R    NaN   house              104  1955.0
# 492      Randy       Tate     R    NaN   house              104  1965.0
# 493      Larry   Pressler     R    NaN  senate              104  1942.0
# 494         Ed     Bryant     R    NaN   house              105  1948.0
# 495      Sonny   Callahan     R    NaN   house              105  1932.0
# 496         Ed     Bryant     R    NaN   house              106  1948.0
# 497      Sonny   Callahan     R    NaN   house              106  1932.0
# 498         Ed     Bryant     R    NaN   house              107  1948.0
# 499      Sonny   Callahan     R    NaN   house              107  1932.0
#
#     method  proportion_male  proportion_female predicted_gender
# 0    ipums              NaN                NaN              NaN
# 1    ipums              NaN                NaN              NaN
# 2    ipums              NaN                NaN              NaN
# 4    ipums              NaN                NaN              NaN
# 5    ipums              NaN                NaN              NaN
# 6    ipums              NaN                NaN              NaN
# 7    ipums              NaN                NaN              NaN
# 8    ipums              NaN                NaN              NaN
# 9    ipums              NaN                NaN              NaN
# 11   ipums              NaN                NaN              NaN
# 12   ipums              NaN                NaN              NaN
# 13   ipums              NaN                NaN              NaN
# 14   ipums              NaN                NaN              NaN
# 15   ipums              NaN                NaN              NaN
# 16   ipums              NaN                NaN              NaN
# 17   ipums              NaN                NaN              NaN
# 19   ipums              NaN                NaN              NaN
# 20   ipums              NaN                NaN              NaN
# 21   ipums              NaN                NaN              NaN
# 24   ipums              NaN                NaN              NaN
# 25   ipums              NaN                NaN              NaN
# 28   ipums              NaN                NaN              NaN
# 29   ipums              NaN                NaN              NaN
# 30   ipums              NaN                NaN              NaN
# 31   ipums              NaN                NaN              NaN
# 32   ipums              NaN                NaN              NaN
# 33   ipums              NaN                NaN              NaN
# 34   ipums              NaN                NaN              NaN
# 35   ipums              NaN                NaN              NaN
# 36   ipums              NaN                NaN              NaN
# ..     ...              ...                ...              ...
# 470    ssa           1.0000             0.0000                M
# 471    ssa           0.9939             0.0061                M
# 472  ipums           0.9799             0.0201                M
# 473  ipums           1.0000             0.0000                M
# 474  ipums           1.0000             0.0000                M
# 475  ipums              NaN                NaN                M
# 476  ipums           1.0000             0.0000                M
# 477  ipums           1.0000             0.0000                M
# 478  ipums           1.0000             0.0000                M
# 479  ipums           1.0000             0.0000                M
# 480    ssa              NaN                NaN                M
# 481    ssa           0.9970             0.0030                M
# 482    ssa           1.0000             0.0000                M
# 483    ssa           1.0000             0.0000                M
# 484  ipums           1.0000             0.0000                M
# 485    ssa           0.9970             0.0030                M
# 486    ssa           1.0000             0.0000                M
# 487    ssa           0.9976             0.0024                M
# 488    ssa           1.0000             0.0000                M
# 489    ssa           1.0000             0.0000                M
# 490    ssa              NaN                NaN                M
# 491    ssa           0.9954             0.0046                M
# 492    ssa           0.9866             0.0134                M
# 493    ssa           0.9970             0.0030                M
# 494    ssa           1.0000             0.0000                M
# 495    ssa           1.0000             0.0000                M
# 496    ssa           1.0000             0.0000                M
# 497    ssa           1.0000             0.0000                M
# 498    ssa           1.0000             0.0000                M
# 499    ssa           1.0000             0.0000                M
#
# [10567 rows x 11 columns]

# %%
# We finally have a dataset with all the info we need! Jeez that took long. 
# Let's create a new column, final gender, that consolidates the gender and predicted gender columns

# %%
def f(x):
    if x['predicted_gender'] != 'M' and x['predicted_gender'] != 'F':
        return x['gender']
    else:
        return x['predicted_gender']

# %%
results['final_gender'] = results.apply(f, axis = 1)

# %%
results.final_gender.isna().value_counts()
# Out:
# False    10567
# Name: final_gender, dtype: int64

# %%
results.to_csv('cleaned_propublica_data.csv')

# %%
results.groupby(['congress_number', 'party', 'chamber']).final_gender.value_counts()
# Out:
# congress_number  party  chamber  final_gender
# 80               D      senate   M                49
#                  R      senate   M                52
#                                  F                 1
# 81               D      senate   M                61
#                  I      senate   M                 1
#                  R      senate   M                46
#                                  F                 1
# 82               D      senate   M                50
#                  I      senate   M                 1
#                  R      senate   M                53
#                                  F                 1
# 83               D      senate   M                54
#                  I      senate   M                 2
#                  R      senate   M                55
#                                  F                 3
# 84               D      senate   M                49
#                  I      senate   M                 3
#                  R      senate   M                48
#                                  F                 1
# 85               D      senate   M                53
#                  I      senate   M                 1
#                  R      senate   M                47
#                                  F                 1
# 86               D      senate   M                67
#                                  F                 1
#                  I      senate   M                 2
#                  R      senate   M                35
#                                  F                 1
# 87               D      senate   M                65
#                                  F                 1
#                                                 ...
# 113              R      senate   M                42
#                                  F                 4
# 114              D      house    M               129
#                                  F                66
#                         senate   M                30
#                                  F                14
#                  I      senate   M                 2
#                  R      house    M               230
#                                  F                23
#                         senate   M                48
#                                  F                 6
# 115              D      house    M               136
#                                  F                68
#                         senate   M                31
#                                  F                17
#                  I      senate   M                 2
#                  R      house    M               227
#                                  F                25
#                         senate   M                49
#                                  F                 6
# 116              D      house    M               148
#                                  F                91
#                         senate   M                28
#                                  F                17
#                  I      house    M                 1
#                         senate   M                 2
#                  R      house    M               188
#                                  F                15
#                         senate   M                45
#                                  F                 8
# Name: final_gender, Length: 230, dtype: int64

# %%
# Let's see if a streamgraph is doable on this, would look very cool. 
# Seems to be something you can do in R.
